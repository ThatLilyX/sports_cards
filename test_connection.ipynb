# %%
import uuid
from IPython.display import display_javascript, display_html, display
import json

class RenderJSON(object):
    def __init__(self, json_data):
        if isinstance(json_data, dict):
            self.json_str = json.dumps(json_data)
        else:
            self.json_str = json_data
        self.uuid = str(uuid.uuid4())

    def _ipython_display_(self):
        display_html('<div id="{}" style="height: 600px; width:100%;"></div>'.format(self.uuid), raw=True)
        display_javascript("""
        require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
        document.getElementById('%s').appendChild(renderjson(%s))
        });
        """ % (self.uuid, self.json_str), raw=True)

# %%
from ebaysdk.finding import Connection

# %%
keywords = 'prizm silver psa10 basketball'

# %%
api = Connection(domain="svcs.sandbox.ebay.com", config_file='test_yaml.yaml', debug=True, siteid="EBAY-US", https=True)

# %%
request = {
        'keywords': 'basketball',
        'itemFilter': [
            {'name': 'condition', 'value': 'new'}
        ],
        'paginationInput': {
            'entriesPerPage': 10,
            'pageNumber': 1
        },
        'sortOrder': 'PricePlusShippingLowest'
    }

# %%
response = api.execute('findItemsByKeywords', request)
# Out:
# 2020-03-06 04:12:53,714 ebaysdk [DEBUG]:execute: verb=findItemsByKeywords data={'keywords': 'basketball', 'paginationInput': {'entriesPerPage': 10, 'pageNumber': 1}, 'itemFilter': [{'name': 'condition', 'value': 'new'}], 'sortOrder': 'PricePlusShippingLowest'}
# 2020-03-06 04:12:53,718 ebaysdk [DEBUG]:REQUEST (16ddcd52-ea33-443e-ac7c-edd4f64e3146): POST https://svcs.sandbox.ebay.com/services/search/FindingService/v1
# 2020-03-06 04:12:53,728 ebaysdk [DEBUG]:headers={'X-EBAY-SOA-SERVICE-NAME': 'FindingService', 'Content-Type': 'text/xml', 'Content-Length': '392', 'X-EBAY-SOA-SERVICE-VERSION': '1.12.0', 'X-EBAY-SOA-RESPONSE-DATA-FORMAT': 'XML', 'X-EBAY-SOA-OPERATION-NAME': 'findItemsByKeywords', 'User-Agent': 'eBaySDK/2.1.5 Python/3.5.4 Darwin/19.3.0', 'X-EBAY-SOA-GLOBAL-ID': 'EBAY-US', 'X-EBAY-SOA-SECURITY-APPNAME': 'JedJed-Test-SBX-369eabc89-ae374269', 'X-EBAY-SDK-REQUEST-ID': '16ddcd52-ea33-443e-ac7c-edd4f64e3146', 'X-EBAY-SOA-REQUEST-DATA-FORMAT': 'XML'}
# 2020-03-06 04:12:53,729 ebaysdk [DEBUG]:body=b'<?xml version=\'1.0\' encoding=\'utf-8\'?><findItemsByKeywordsRequest xmlns="http://www.ebay.com/marketplace/search/v1/services"><itemFilter><name>condition</name><value>new</value></itemFilter><keywords>basketball</keywords><paginationInput><entriesPerPage>10</entriesPerPage><pageNumber>1</pageNumber></paginationInput><sortOrder>PricePlusShippingLowest</sortOrder></findItemsByKeywordsRequest>'
# 2020-03-06 04:12:53,903 ebaysdk [DEBUG]:RESPONSE (16ddcd52-ea33-443e-ac7c-edd4f64e3146):
# 2020-03-06 04:12:53,904 ebaysdk [DEBUG]:elapsed time=0:00:00.163988
# 2020-03-06 04:12:53,905 ebaysdk [DEBUG]:status code=200
# 2020-03-06 04:12:53,906 ebaysdk [DEBUG]:headers={'Content-Type': 'text/xml;charset=UTF-8', 'X-EBAY-SOA-SERVICE-METRICS': '79366200', 'X-EBAY-SOA-REQUEST-ID': '170af1e7-5160-ac7a-a702-e4c2ffedabd4', 'X-EBAY-SOA-MESSAGE-PROTOCOL': 'NONE', 'X-EBAY-SOA-GLOBAL-ID': 'EBAY-US', 'Date': 'Fri, 06 Mar 2020 09:12:53 GMT', 'X-EBAY-SOA-SERVICE-NAME': '{http://www.ebay.com/marketplace/search/v1/services}FindingService', 'Transfer-Encoding': 'chunked', 'X-EBAY-SOA-LOCALE-LIST': 'en-US_US', 'X-EBAY-SOA-RESPONSE-DATA-FORMAT': 'XML', 'X-EBAY-SOA-OPERATION-NAME': 'findItemsByKeywords', 'Server': 'Apache-Coyote/1.1', 'X-EBAY-SOA-SERVICE-VERSION': '1.13.0'}
# 2020-03-06 04:12:53,909 ebaysdk [DEBUG]:content=<?xml version='1.0' encoding='UTF-8'?><findItemsByKeywordsResponse xmlns="http://www.ebay.com/marketplace/search/v1/services"><ack>Success</ack><version>1.13.0</version><timestamp>2020-03-06T09:12:53.860Z</timestamp><searchResult count="0"/><paginationOutput><pageNumber>0</pageNumber><entriesPerPage>10</entriesPerPage><totalPages>0</totalPages><totalEntries>0</totalEntries></paginationOutput><itemSearchURL>https://shop.sandbox.ebay.com/i.html?_nkw=basketball&amp;_ddo=1&amp;_ipg=10&amp;_pgn=1&amp;_sop=15</itemSearchURL></findItemsByKeywordsResponse>
# 2020-03-06 04:12:53,911 ebaysdk [DEBUG]:total time=0.19376492500305176

# %%
RenderJSON(response.json())
# Out:
# <div id="aad3f828-5894-4a9b-b957-39479d31b138" style="height: 600px; width:100%;"></div>
