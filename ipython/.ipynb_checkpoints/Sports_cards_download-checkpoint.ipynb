# %%
import requests
from bs4 import BeautifulSoup
from collections import defaultdict
import pandas as pd

# %%
def get_url(pageNum, auction=True, keywords="prizm+silver+psa10+basketball"):
    if auction:
        insert_mode = r"LH_Auction=1"
    else:
        insert_mode = r"LH_BIN=1"
    url_partA = r"https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&"+insert_mode+"&_nkw="+keywords
    url_partB = r"&_pgn="+str(pageNum)+"&_skc="+str(50*(pageNum-1))+"&rt=nc"
    url_partC = r"&_sacat=0"
    if pageNum == 1:
        url = url_partA + url_partC
    else:
        url = url_partA + url_partB
    return url

# %% [markdown]
# ----

# %% [markdown]
# **Download Auctions**

# %%
data = defaultdict(list)
for pageNum in range(1, 20):
    url = get_url(pageNum)
    print(url)
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')
    items = soup.findAll(class_='sresult lvresult clearfix li')
    print(r"Page "+str(pageNum)+r": "+str(len(items)))
    for item in items:
        time = item.find(class_='tme').contents[1].contents[0]
        title = item.find(class_='lvtitle').find(class_='vip').contents[0]
        item_url = item.find(class_='lvtitle').find(class_='vip')['href']
        price = item.find(class_='lvprice prc').find(class_="bold bidsold").contents[0]
        price = float(str(price).replace("$", "").replace(",", ""))
        bids = item.find(class_='lvformat').contents[1].contents[0]
        bids = int(bids.split(" ")[0])

        data["Timestamp"].append(time)
        data["Title"].append(title)
        data["URL"].append(item_url)
        data["Price"].append(price)
        data["Bids"].append(bids)
# Out:
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_sacat=0
# Page 1: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_pgn=2&_skc=50&rt=nc
# Page 2: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_pgn=3&_skc=100&rt=nc
# Page 3: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_pgn=4&_skc=150&rt=nc
# Page 4: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_pgn=5&_skc=200&rt=nc
# Page 5: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_pgn=6&_skc=250&rt=nc
# Page 6: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_pgn=7&_skc=300&rt=nc
# Page 7: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_pgn=8&_skc=350&rt=nc
# Page 8: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_pgn=9&_skc=400&rt=nc
# Page 9: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_pgn=10&_skc=450&rt=nc
# Page 10: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_pgn=11&_skc=500&rt=nc
# Page 11: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_pgn=12&_skc=550&rt=nc
# Page 12: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_pgn=13&_skc=600&rt=nc
# Page 13: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_pgn=14&_skc=650&rt=nc
# Page 14: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_pgn=15&_skc=700&rt=nc
# Page 15: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_pgn=16&_skc=750&rt=nc
# Page 16: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_pgn=17&_skc=800&rt=nc
# Page 17: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_pgn=18&_skc=850&rt=nc
# Page 18: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_Auction=1&_nkw=prizm+silver+psa10+basketball&_pgn=19&_skc=900&rt=nc
# Page 19: 50

# %%
auction_data = pd.DataFrame(data).set_index("Timestamp")
auction_data.head()
# Out:
#               Bids   Price                                              Title  \
# Timestamp
# Mar-18 17:11    14    34.0  2017-18 Panini Prizm Silver Ben Simmons #9 PSA...
# Mar-18 17:06     8    39.0  2017-18 Panini Prizm Silver Ben Simmons #9 PSA...
# Mar-18 17:02     8    36.0  2017-18 Panini Prizm Silver Ben Simmons #9 PSA...
# Mar-18 16:38     2    70.0  Kobe Bryant 2018 Panini Prizm SILVER PRIZM #15...
# Mar-18 16:34     8  2225.0  2019-20 Panini Prizm Silver Zion Williamson RC...
#
#                                                             URL
# Timestamp
# Mar-18 17:11  https://www.ebay.com/itm/2017-18-Panini-Prizm-...
# Mar-18 17:06  https://www.ebay.com/itm/2017-18-Panini-Prizm-...
# Mar-18 17:02  https://www.ebay.com/itm/2017-18-Panini-Prizm-...
# Mar-18 16:38  https://www.ebay.com/itm/Kobe-Bryant-2018-Pani...
# Mar-18 16:34  https://www.ebay.com/itm/2019-20-Panini-Prizm-...

# %%
auction_data.to_csv(r"../output/auction_data.csv")

# %% [markdown]
# ----

# %% [markdown]
# **Download "Buy-it-now"**

# %%
raw_data = defaultdict(list)
for pageNum in range(1, 20):
    url = get_url(pageNum, auction=False)
    print(url)
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')
    items = soup.findAll(class_='sresult lvresult clearfix li')
    print(r"Page "+str(pageNum)+r": "+str(len(items)))
    for item in items:
        title = item.find(class_='lvtitle').find(class_='vip').contents[0]
        try:
            price = item.find(class_='lvprice prc').find(class_="bold bidsold").find(class_="sboffer").contents[0]
        except AttributeError:
            price = item.find(class_='lvprice prc').find(class_="bold bidsold").contents[0]
        price = float(str(price).replace("$", "").replace(",", ""))
        item_url = item.find(class_='lvtitle').find(class_='vip')['href']
        item_page = requests.get(item_url)
        item_soup = BeautifulSoup(item_page.text, 'html.parser')
        
        try:
            date = item_soup.find(id="bb_tlft").contents[0].replace(r"/n", "").replace(r"/t", "")
        except AttributeError:
            date = "N/A"

        raw_data["Timestamp"].append(date)
        raw_data["Title"].append(title)
        raw_data["URL"].append(item_url)
        raw_data["Price"].append(price)
        raw_data["Bids"].append("N/A")
# Out:
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_sacat=0
# Page 1: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_pgn=2&_skc=50&rt=nc
# Page 2: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_pgn=3&_skc=100&rt=nc
# Page 3: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_pgn=4&_skc=150&rt=nc
# Page 4: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_pgn=5&_skc=200&rt=nc
# Page 5: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_pgn=6&_skc=250&rt=nc
# Page 6: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_pgn=7&_skc=300&rt=nc
# Page 7: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_pgn=8&_skc=350&rt=nc
# Page 8: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_pgn=9&_skc=400&rt=nc
# Page 9: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_pgn=10&_skc=450&rt=nc
# Page 10: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_pgn=11&_skc=500&rt=nc
# Page 11: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_pgn=12&_skc=550&rt=nc
# Page 12: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_pgn=13&_skc=600&rt=nc
# Page 13: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_pgn=14&_skc=650&rt=nc
# Page 14: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_pgn=15&_skc=700&rt=nc
# Page 15: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_pgn=16&_skc=750&rt=nc
# Page 16: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_pgn=17&_skc=800&rt=nc
# Page 17: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_pgn=18&_skc=850&rt=nc
# Page 18: 50
# https://www.ebay.com/sch/i.html?_from=R40&_sacat=0&LH_Sold=1&_udlo=&_udhi=&_samilow=&_samihi=&_sadis=15&_stpos=07014&_sop=13&_dmd=1&LH_Complete=1&_fosrp=1&LH_BIN=1&_nkw=prizm+silver+psa10+basketball&_pgn=19&_skc=900&rt=nc
# Page 19: 50

# %%
buy_it_now = pd.DataFrame(raw_data).set_index("Timestamp")
buy_it_now.head()
# Out:
#                   Bids    Price  \
# Timestamp
#
#                   N/A   130.00
# 			Mar 18, 2020    N/A   200.00
#
#                   N/A  1000.00
# 			Mar 18, 2020    N/A    47.75
#
#                   N/A  1450.00
# 			Mar 18, 2020
#
#
# 			Mar 18, 2020
#
#
# 			Mar 18, 2020
#
#                                                                Title  \
# Timestamp
#
#                   2018-19 Panini Prizm Lebron James Silver Prizm...
# 			Mar 18, 2020    2019-20 LeBron James Donruss Optic Silver Holo...
#
#                   2017-18 Prizm Silver & Select Scope Jayson Tat...
# 			Mar 18, 2020    2019-20 Panini Prizm Silver Prizm #210 Kevin D...
#
#                   LUKA DONCIC 2018/19 PANINI PRIZM #280 RC ROOKI...
# 			Mar 18, 2020
#
#
# 			Mar 18, 2020
#
#
# 			Mar 18, 2020
#
#                                                                  URL
# Timestamp
#
#                   https://www.ebay.com/itm/2018-19-Panini-Prizm-...
# 			Mar 18, 2020    https://www.ebay.com/itm/2019-20-LeBron-James-...
#
#                   https://www.ebay.com/itm/2017-18-Prizm-Silver-...
# 			Mar 18, 2020    https://www.ebay.com/itm/2019-20-Panini-Prizm-...
#
#                   https://www.ebay.com/itm/LUKA-DONCIC-2018-19-P...
# 			Mar 18, 2020
#
#
# 			Mar 18, 2020
#
#
# 			Mar 18, 2020

# %%
buy_it_now.to_csv(r"../output/buy_it_now.csv")

# %%
buy_it_now.head()
# Out:
#                   Bids    Price  \
# Timestamp
#
#                   N/A   130.00
# 			Mar 18, 2020    N/A   200.00
#
#                   N/A  1000.00
# 			Mar 18, 2020    N/A    47.75
#
#                   N/A  1450.00
# 			Mar 18, 2020
#
#
# 			Mar 18, 2020
#
#
# 			Mar 18, 2020
#
#                                                                Title  \
# Timestamp
#
#                   2018-19 Panini Prizm Lebron James Silver Prizm...
# 			Mar 18, 2020    2019-20 LeBron James Donruss Optic Silver Holo...
#
#                   2017-18 Prizm Silver & Select Scope Jayson Tat...
# 			Mar 18, 2020    2019-20 Panini Prizm Silver Prizm #210 Kevin D...
#
#                   LUKA DONCIC 2018/19 PANINI PRIZM #280 RC ROOKI...
# 			Mar 18, 2020
#
#
# 			Mar 18, 2020
#
#
# 			Mar 18, 2020
#
#                                                                  URL
# Timestamp
#
#                   https://www.ebay.com/itm/2018-19-Panini-Prizm-...
# 			Mar 18, 2020    https://www.ebay.com/itm/2019-20-LeBron-James-...
#
#                   https://www.ebay.com/itm/2017-18-Prizm-Silver-...
# 			Mar 18, 2020    https://www.ebay.com/itm/2019-20-Panini-Prizm-...
#
#                   https://www.ebay.com/itm/LUKA-DONCIC-2018-19-P...
# 			Mar 18, 2020
#
#
# 			Mar 18, 2020
#
#
# 			Mar 18, 2020
